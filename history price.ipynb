# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import os
import requests
import psycopg2
import psycopg2.extras

# %% [markdown]
# # IEX API Credentials

# %%
token = "pk_5925316dd7194aa583d7e80711bbd661"

base_url = 'https://cloud.iexapis.com/v1'

resp = requests.get(base_url + '/status')

resp
# Out:
# <Response [200]>

# %% [markdown]
# # Stocks To Collect Data On

# %%
tickers= ["AAPL", "FB", "ADBE", "INTC", "PYPL", "BABA", "QCOM", "SHOP", "AMD", "MSFT"]
          
# "PYPL", "BABA", "QCOM", "SHOP", "AMD", "MSFT"]

## list of tickers in Technology: 
# 1 - 4> "AAPL": Apple, "MSFT": Microsoft Corporation, "INTC":  Intel Corporation, "AMZN": Amazon
# 5 - 8> "GOOG": Alphabet Inc Class C, "NVDA": NVIDIA Corporation, "CRM": salesforce.com, inc., "BABA": Alibaba Group Holding Ltd - ADR
# 9 - 12> "TSLA": Tesla Inc, "XRX": Xerox Holdings Corp, "PYPL": Paypal Holdings Inc, "NTAP": NetApp Inc.
# 13 - 16> "AVGO": Broadcom Inc, "GLW": Corning Incorporated, "MTCH": Match Group Inc, "FANG": Diamondback Energy Inc
# 17 - 20> "NFLX": Netflix Inc, "SWKS": Skyworks Solutions Inc, "GME": GameStop Corp, "ATVI": Activision Blizzard, Inc
# 21 - 24> "ADBE": Adobe Inc, "AMD": Advanced Micro Devices, Inc., "IBM": IBM Common Stock, "A": Agilent Technologies Inc
# 25 - 28> "LOW": Lowe`s Companies Inc, "CSCO":  Cisco Systems Inc, "EA": Electronic Arts Inc., "AMAT": Applied Materials, Inc.
# 29 - 32> "GOOGL": Alphabet Inc Class A, "XG": Vislink Technologies Inc, "YELP": Yelp Inc, "XLK": Technology Select Sector SPDR Fund
# 33 - 36> "BYD": BYD Ord Shs H, "LRCX": Lam Research Corporation, "XLNX": Xilinx, Inc., "MU": Micron Technology, Inc.
# 37 - 40> "KLAC": KLA Corp, "MXIM": Maxim Integrated Products Inc., "ACN": Accenture Plc, "TXN": Texas Instruments Incorporated
# 41 - 44> "INTU":  Intuit Inc., "HPQ": HP Inc, "ANSS": ANSYS, Inc., "ADSK": Autodesk, Inc.
# 45 - 48> "MA": Mastercard Inc, "D": Dominion Energy Inc, "CTXS": Citrix Systems, Inc., "ORCL": Oracle Corporation

# %% [markdown]
# ## historical price data

# %%
import pyEX as p
c = p.Client(api_token='pk_5925316dd7194aa583d7e80711bbd661', version='stable')

# %%
## Apple AAPL -- 5y
sym='AAPL'
timeframe='5y'
df_AAPL = c.chartDF(symbol=sym, timeframe=timeframe)
df_AAPL.head()
# Out:
#             change  changeOverTime  changePercent   close  fClose     fHigh  \
# date
# 2021-04-01    0.00        0.000000         0.0000  123.00  123.00  124.1800
# 2021-03-31   -0.85       -0.006911        -0.0069  122.15  122.15  123.5200
# 2021-03-30   -2.25       -0.025203        -0.0184  119.90  119.90  120.4031
# 2021-03-29    1.49       -0.013089         0.0124  121.39  121.39  122.5800
# 2021-03-26   -0.18       -0.014553        -0.0015  121.21  121.21  121.4800
#
#                 fLow   fOpen    fVolume      high    ...        open subkey  \
# date                                                 ...
# 2021-04-01  122.4900  123.66   75089134  124.1800    ...      123.66
# 2021-03-31  121.1500  121.65  118323826  123.5200    ...      121.65
# 2021-03-30  118.8600  120.11   85671919  120.4031    ...      120.11
# 2021-03-29  120.7299  121.65   80819203  122.5800    ...      121.65
# 2021-03-26  118.9200  120.35   94071234  121.4800    ...      120.35
#
# ...

# %%
## Facebook FB -- 5y
sym='FB'
timeframe='5y'
df_FB = c.chartDF(symbol=sym, timeframe=timeframe)
df_FB.tail()
# Out:
#             change  changeOverTime  changePercent   close  fClose   fHigh  \
# date
# 2016-04-08    1.64       -0.629579         0.0150  110.63  110.63  114.33
# 2016-04-07    3.01       -0.619500         0.0272  113.64  113.64  114.89
# 2016-04-06    0.07       -0.619266         0.0006  113.71  113.71  113.81
# 2016-04-05   -1.49       -0.624255        -0.0131  112.22  112.22  113.32
# 2016-04-04    0.33       -0.623150         0.0029  112.55  112.55  114.55
#
#                 fLow   fOpen   fVolume    high    ...       open subkey  \
# date                                              ...
# 2016-04-08  109.9000  114.25  48497808  114.33    ...     114.25
# 2016-04-07  113.0663  113.79  20714537  114.89    ...     113.79
# 2016-04-06  112.4200  112.47  20814640  113.81    ...     112.47
# 2016-04-05  111.9000  112.11  22962365  113.32    ...     112.11
# 2016-04-04  111.6100  114.07  48487913  114.55    ...     114.07
#
# ...

# %%
## Adobe Inc ADDBE -- 5y
sym='ADBE'
timeframe='5y'
df_ADBE = c.chartDF(symbol=sym, timeframe=timeframe)
df_ADBE.head()
# Out:
#             change  changeOverTime  changePercent   close  fClose     fHigh  \
# date
# 2021-04-01    0.00        0.000000         0.0000  483.34  483.34  487.0400
# 2021-03-31   -7.97       -0.016489        -0.0165  475.37  475.37  482.4100
# 2021-03-30   -9.91       -0.036993        -0.0208  465.46  465.46  469.0925
# 2021-03-29    3.86       -0.029006         0.0083  469.32  469.32  472.0000
# 2021-03-26   -0.23       -0.029482        -0.0005  469.09  469.09  469.7700
#
#               fLow   fOpen  fVolume      high   ...       open subkey symbol  \
# date                                            ...
# 2021-04-01  480.71  483.12  2664694  487.0400   ...     483.12          ADBE
# 2021-03-31  468.70  469.70  3155889  482.4100   ...     469.70          ADBE
# 2021-03-30  461.50  462.58  2436593  469.0925   ...     462.58          ADBE
# 2021-03-29  462.50  469.03  3142203  472.0000   ...     469.03          ADBE
# ...

# %%
## Intel Corporation INTC -- 5y
sym='INTC'
timeframe='5y'
df_INTC = c.chartDF(symbol=sym, timeframe=timeframe)
df_INTC.tail()
# Out:
#             change  changeOverTime  changePercent  close   fClose    fHigh  \
# date
# 2016-04-08   -0.04       -0.509992        -0.0013  31.63  27.7279  28.0697
# 2016-04-07   -0.08       -0.511232        -0.0025  31.55  27.6577  27.9646
# 2016-04-06    0.53       -0.503021         0.0168  32.08  28.1223  28.2538
# 2016-04-05   -0.18       -0.505809        -0.0056  31.90  27.9646  28.1574
# 2016-04-04    0.10       -0.504260         0.0031  32.00  28.0522  28.3853
#
#                fLow    fOpen   fVolume   high    ...      open subkey symbol  \
# date                                             ...
# 2016-04-08  27.5964  27.8418  17031882  32.02    ...     31.76          INTC
# 2016-04-07  27.4824  27.9558  23738226  31.90    ...     31.89          INTC
# 2016-04-06  27.8506  28.0259  15740607  32.23    ...     31.97          INTC
# 2016-04-05  27.8068  27.9558  20080011  32.12    ...     31.89          INTC
# ...

# %%
## Paypal Holdings Inc PYPL -- 5y
sym='PYPL'
timeframe='5y'
df_PYPL = c.chartDF(symbol=sym, timeframe=timeframe)
df_PYPL.head()
# Out:
#             change  changeOverTime  changePercent   close  fClose     fHigh  \
# date
# 2021-04-01    0.00        0.000000         0.0000  247.54  247.54  252.6492
# 2021-03-31   -4.70       -0.018987        -0.0190  242.84  242.84  245.2300
# 2021-03-30   -6.30       -0.044437        -0.0259  236.54  236.54  238.3600
# 2021-03-29   -0.87       -0.047952        -0.0037  235.67  235.67  243.2000
# 2021-03-26    5.36       -0.026299         0.0227  241.03  241.03  241.3100
#
#                 fLow     fOpen  fVolume      high   ...         open subkey  \
# date                                                ...
# 2021-04-01  246.0400  248.0400  6990135  252.6492   ...     248.0400
# 2021-03-31  237.2700  238.1100  7633372  245.2300   ...     238.1100
# 2021-03-30  232.6301  236.8800  6241995  238.3600   ...     236.8800
# 2021-03-29  233.6100  241.5800  7510936  243.2000   ...     241.5800
# 2021-03-26  232.3000  233.6187  8217621  241.3100   ...     233.6187
#
# ...

# %%
## Alibaba Group Holding Ltd BABA -- 5y
sym='BABA'
timeframe='5y'
df_BABA = c.chartDF(symbol=sym, timeframe=timeframe)
df_BABA.tail()
# Out:
#             change  changeOverTime  changePercent  close  fClose  fHigh  \
# date
# 2016-04-08   -0.24       -0.654707        -0.0031  77.47   77.47  78.76
# 2016-04-07    0.14       -0.654083         0.0018  77.61   77.61  78.60
# 2016-04-06    1.07       -0.649314         0.0138  78.68   78.68  79.15
# 2016-04-05   -1.36       -0.655375        -0.0173  77.32   77.32  78.30
# 2016-04-04    1.76       -0.647531         0.0228  79.08   79.08  79.55
#
#                fLow  fOpen   fVolume   high    ...      open subkey symbol  \
# date                                           ...
# 2016-04-08  76.6210  78.27   8401183  78.76    ...     78.27          BABA
# 2016-04-07  77.1825  77.60  10937914  78.60    ...     77.60          BABA
# 2016-04-06  77.1900  77.30   9071942  79.15    ...     77.30          BABA
# 2016-04-05  76.9100  78.20   9603910  78.30    ...     78.20          BABA
# 2016-04-04  78.3200  78.33   9817315  79.55    ...     78.33          BABA
#
# ...

# %%
## QUALCOMM, Inc QCOM -- 5y
sym='QCOM'
timeframe='5y'
df_QCOM = c.chartDF(symbol=sym, timeframe=timeframe)
df_QCOM.head()
# Out:
#             change  changeOverTime  changePercent   close  fClose     fHigh  \
# date
# 2021-04-01    0.00        0.000000         0.0000  137.79  137.79  138.4321
# 2021-03-31   -5.20       -0.037739        -0.0377  132.59  132.59  133.5200
# 2021-03-30   -2.48       -0.055737        -0.0187  130.11  130.11  131.2400
# 2021-03-29    1.16       -0.047318         0.0089  131.27  131.27  133.3400
# 2021-03-26    1.72       -0.034836         0.0131  132.99  132.99  133.3500
#
#                fLow   fOpen   fVolume      high    ...       open subkey  \
# date                                               ...
# 2021-04-01  133.600  134.50  14069555  138.4321    ...     134.50
# 2021-03-31  130.570  130.96   8361293  133.5200    ...     130.96
# 2021-03-30  129.065  130.17   7097298  131.2400    ...     130.17
# 2021-03-29  129.770  132.54   9750057  133.3400    ...     132.54
# 2021-03-26  127.040  127.06  11071560  133.3500    ...     127.06
#
# ...

# %%
## Shopify Inc SHOP -- 5y
sym='SHOP'
timeframe='5y'
df_SHOP = c.chartDF(symbol=sym, timeframe=timeframe)
df_SHOP.tail()
# Out:
#             change  changeOverTime  changePercent  close  fClose    fHigh  \
# date
# 2016-04-08    0.03       -0.974425         0.0010  29.55   29.55  30.0000
# 2016-04-07   -0.34       -0.974719        -0.0115  29.21   29.21  29.6900
# 2016-04-06    0.29       -0.974468         0.0099  29.50   29.50  29.7399
# 2016-04-05   -0.75       -0.975117        -0.0254  28.75   28.75  29.2400
# 2016-04-04    0.55       -0.974641         0.0191  29.30   29.30  29.9889
#
#               fLow  fOpen  fVolume     high   ...      open subkey symbol  \
# date                                          ...
# 2016-04-08  29.240  29.42   443368  30.0000   ...     29.42          SHOP
# 2016-04-07  28.941  29.47   320422  29.6900   ...     29.47          SHOP
# 2016-04-06  28.780  28.83   493783  29.7399   ...     28.83          SHOP
# 2016-04-05  28.640  29.24   558670  29.2400   ...     29.24          SHOP
# 2016-04-04  28.750  29.02  1619759  29.9889   ...     29.02          SHOP
#
# ...

# %%
## Advanced Micro Devices, Inc AMD -- 5y
sym='AMD'
timeframe='5y'
df_AMD = c.chartDF(symbol=sym, timeframe=timeframe)
df_AMD.head()
# Out:
#             change  changeOverTime  changePercent  close  fClose    fHigh  \
# date
# 2021-04-01    0.00        0.000000         0.0000  81.09   81.09  81.3100
# 2021-03-31   -2.59       -0.031940        -0.0319  78.50   78.50  79.1300
# 2021-03-30   -2.50       -0.062770        -0.0318  76.00   76.00  76.5600
# 2021-03-29    1.14       -0.048711         0.0150  77.14   77.14  78.0200
# 2021-03-26    0.27       -0.045382         0.0035  77.41   77.41  77.4995
#
#              fLow   fOpen   fVolume     high    ...       open subkey symbol  \
# date                                            ...
# 2021-04-01  79.48  80.155  40182380  81.3100    ...     80.155           AMD
# 2021-03-31  76.52  76.570  43659455  79.1300    ...     76.570           AMD
# 2021-03-30  74.85  76.470  39169250  76.5600    ...     76.470           AMD
# 2021-03-29  76.26  77.030  37144298  78.0200    ...     77.030           AMD
# 2021-03-26  75.03  76.620  49148659  77.4995    ...     76.620           AMD
# ...

# %%
## Microsoft Corporation MSFT -- 5y
sym='MSFT'
timeframe='5y'
df_MSFT = c.chartDF(symbol=sym, timeframe=timeframe)
df_MSFT.tail()
# Out:
#             change  changeOverTime  changePercent  close   fClose    fHigh  \
# date
# 2016-04-08    0.11       -0.775449         0.0020  54.42  49.9016  50.6902
# 2016-04-07    0.04       -0.775284         0.0007  54.46  49.9383  50.3509
# 2016-04-06    0.66       -0.772560         0.0121  55.12  50.5435  50.6168
# 2016-04-05   -0.56       -0.774871        -0.0102  54.56  50.0300  50.7085
# 2016-04-04    0.87       -0.771281         0.0159  55.43  50.8277  51.0387
#
#                fLow    fOpen   fVolume   high    ...      open subkey symbol  \
# date                                             ...
# 2016-04-08  49.8099  50.1309  22167223  55.28    ...     54.67          MSFT
# 2016-04-07  49.7274  50.3142  19225092  54.91    ...     54.87          MSFT
# 2016-04-06  49.7090  49.8466  21188682  55.20    ...     54.36          MSFT
# 2016-04-05  49.9383  50.6077  19272255  55.30    ...     55.19          MSFT
# ...

# %% [markdown]
# ## convert to csv

# %%
df_AAPL.to_csv(r'C:/Users/HOA PHAT/Downloads/uci/stats 170A/capstone/data/AAPL_hist_price.csv', index = False)

# %%
df_FB.to_csv(r'C:/Users/HOA PHAT/Downloads/uci/stats 170A/capstone/data/FB_hist_price.csv', index = False)

# %%
df_ADBE.to_csv(r'C:/Users/HOA PHAT/Downloads/uci/stats 170A/capstone/data/ADBE_hist_price.csv', index = False)

# %%
df_INTC.to_csv(r'C:/Users/HOA PHAT/Downloads/uci/stats 170A/capstone/data/INTC_hist_price.csv', index = False)

# %%
df_PYPL.to_csv(r'C:/Users/HOA PHAT/Downloads/uci/stats 170A/capstone/data/PYPL_hist_price.csv', index = False)

# %%
df_BABA.to_csv(r'C:/Users/HOA PHAT/Downloads/uci/stats 170A/capstone/data/BABA_hist_price.csv', index = False)

# %%
df_QCOM.to_csv(r'C:/Users/HOA PHAT/Downloads/uci/stats 170A/capstone/data/QCOM_hist_price.csv', index = False)

# %%
df_SHOP.to_csv(r'C:/Users/HOA PHAT/Downloads/uci/stats 170A/capstone/data/SHOP_hist_price.csv', index = False)

# %%
df_AMD.to_csv(r'C:/Users/HOA PHAT/Downloads/uci/stats 170A/capstone/data/AMD_hist_price.csv', index = False)

# %%
df_MSFT.to_csv(r'C:/Users/HOA PHAT/Downloads/uci/stats 170A/capstone/data/MSFT_hist_price.csv', index = False)

# %% [markdown]
# ## Save to pickle

# %%
import pickle
with open('AAPL_price.pickle', 'wb') as f:
    pickle.dump(df_AAPL, f)

# %%
with open('FB_price.pickle', 'wb') as f:
    pickle.dump(df_FB, f)

# %%
with open('ADBE_price.pickle', 'wb') as f:
    pickle.dump(df_ADBE, f)

# %%
with open('INTC_price.pickle', 'wb') as f:
    pickle.dump(df_INTC, f)

# %%
with open('PYPL_price.pickle', 'wb') as f:
    pickle.dump(df_PYPL, f)

# %%
with open('BABA_price.pickle', 'wb') as f:
    pickle.dump(df_BABA, f)

# %%
with open('QCOM_price.pickle', 'wb') as f:
    pickle.dump(df_QCOM, f)

# %%
with open('SHOP_price.pickle', 'wb') as f:
    pickle.dump(df_SHOP, f)

# %%
with open('AMD_price.pickle', 'wb') as f:
    pickle.dump(df_AMD, f)

# %%
with open('MSFT_price.pickle', 'wb') as f:
    pickle.dump(df_MSFT, f)

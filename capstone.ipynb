# %%
import pandas as pd
import os
import requests
# Out:
# C:\Users\imaia\Anaconda3\lib\site-packages\requests\__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.3) or chardet (4.0.0) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
token = "pk_8461a849e72a477296d96c3b9c8ecd2f"

base_url = 'https://cloud.iexapis.com/v1'

resp = requests.get(base_url + '/status')

resp
# Out:
# <Response [200]>

# %% [markdown]
# ## historical price data for Apple

# %%
params = {'token': token}

apple_historical = requests.get(base_url+'/stock/AAPL/chart', params=params)

# %%
apple_historical

df = pd.DataFrame(apple_historical.json())

df
# Out:
#     change  changeOverTime  changePercent    close        date   fClose  \
# 0    0.000        0.000000         0.0000  135.390  2021-02-10  135.390
# 1   -0.260       -0.001920        -0.0019  135.130  2021-02-11  135.130
# 2    0.240       -0.000148         0.0018  135.370  2021-02-12  135.370
# 3   -2.180       -0.016249        -0.0161  133.190  2021-02-16  133.190
# 4   -2.350       -0.033607        -0.0176  130.840  2021-02-17  130.840
# 5   -1.130       -0.041953        -0.0086  129.710  2021-02-18  129.710
# 6    0.160       -0.040771         0.0012  129.870  2021-02-19  129.870
# 7   -3.870       -0.069355        -0.0298  126.000  2021-02-22  126.000
# 8   -0.140       -0.070389        -0.0011  125.860  2021-02-23  125.860
# 9   -0.510       -0.074156        -0.0041  125.350  2021-02-24  125.350
# 10  -4.360       -0.106359        -0.0348  120.990  2021-02-25  120.990
# 11   0.270       -0.104365         0.0022  121.260  2021-02-26  121.260
# ...

# %%
params = {'token': token,
          '_range': '1m'}

endpoint = '/stock/AAPL/news'
apple_news = requests.get(base_url+endpoint, params=params)

# %%
df = pd.DataFrame(apple_news.json())

df.head()
# Out:
#         datetime  hasPaywall  \
# 0  1615358553000       False
# 1  1615356441811       False
# 2  1615354699000       False
# 3  1615353483000       False
# 4  1615353268000       False
#
#                                             headline  \
# 0  Apple to Start Making iPhone 12 in India? Foxc...
# 1  Samsung to pip Apple in Q1 2021 smartphone pro...
# 2    Tesla-Aktien über Nacht um 20 Prozent gestiegen
# 3  N.H. man credits Apple watch with saving his l...
# 4  News24.com | Thousands of startups file compla...
#
#                                                image lang related  \
# 0  https://cloud.iexapis.com/v1/news/image/769d5f...   en    AAPL
# 1  https://cloud.iexapis.com/v1/news/image/57d7dc...   en    AAPL
# 2  https://cloud.iexapis.com/v1/news/image/531426...   de    AAPL
# 3  https://cloud.iexapis.com/v1/news/image/fe182d...   en    AAPL
# 4  https://cloud.iexapis.com/v1/news/image/c7bc1d...   en    AAPL
#
# ...

# %%
params = {'token': token,
          'from' : 2019}

apple_financials = requests.get(base_url+'/time-series/reported_financials/AAPL/10-Q', params=params)

apple_financials
# Out:
# <Response [200]>

# %%
df = pd.DataFrame(apple_financials.json())

df.head()
# Out:
#    AccountsPayableCurrent  AccountsReceivableNetCurrent  \
# 0             44293000000                   18077000000
# 1             30443000000                   15085000000
# 2             29115000000                   14148000000
# 3             45111000000                   20970000000
# 4             32421000000                   15722000000
#
#    AccruedIncomeTaxesNoncurrent  \
# 0                   30948000000
# 1                   30986000000
# 2                   30521000000
# 3                   28198000000
# 4                   28188000000
#
#    AccumulatedDepreciationDepletionAndAmortizationPropertyPlantAndEquipment  \
# 0                                        51929000000
# 1                                        54290000000
# 2                                        56348000000
# 3                                        60959000000
# 4                                        62854000000
#
#    AccumulatedOtherComprehensiveIncomeLossNetOfTax  \
# ...

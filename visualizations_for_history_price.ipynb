# %% [markdown]
# ## import library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# ## import data

# %%
df_price = pd.read_csv('merge_hist_price.csv')

# %%
df_AAPL = pd.read_csv('AAPL_hist_price.csv')

# %%
df_FB = pd.read_csv('FB_hist_price.csv')

# %%
df_ADBE = pd.read_csv('ADBE_hist_price.csv')

# %%
df_AMD = pd.read_csv('AMD_hist_price.csv')

# %%
df_BABA = pd.read_csv('BABA_hist_price.csv')

# %%
df_INTC = pd.read_csv('INTC_hist_price.csv')

# %%
df_MSFT = pd.read_csv('MSFT_hist_price.csv')

# %%
df_PYPL = pd.read_csv('PYPL_hist_price.csv')

# %%
df_QCOM = pd.read_csv('QCOM_hist_price.csv')

# %%
df_SHOP = pd.read_csv('SHOP_hist_price.csv')

# %% [markdown]
# ## modify columns for plotting

# %%
# set label as DateTimeIndex
df_AAPL['label'] = pd.DatetimeIndex(df_AAPL.label)
# set index for label
df_AAPL = df_AAPL.set_index('label')
df_AAPL.head()
# Out:
#             change  changeOverTime  changePercent   close  fClose     fHigh  \
# label
# 2021-04-01    0.00        0.000000         0.0000  123.00  123.00  124.1800
# 2021-03-31   -0.85       -0.006911        -0.0069  122.15  122.15  123.5200
# 2021-03-30   -2.25       -0.025203        -0.0184  119.90  119.90  120.4031
# 2021-03-29    1.49       -0.013089         0.0124  121.39  121.39  122.5800
# 2021-03-26   -0.18       -0.014553        -0.0015  121.21  121.21  121.4800
#
#                 fLow   fOpen    fVolume      high    ...        open subkey  \
# label                                                ...
# 2021-04-01  122.4900  123.66   75089134  124.1800    ...      123.66    NaN
# 2021-03-31  121.1500  121.65  118323826  123.5200    ...      121.65    NaN
# 2021-03-30  118.8600  120.11   85671919  120.4031    ...      120.11    NaN
# 2021-03-29  120.7299  121.65   80819203  122.5800    ...      121.65    NaN
# 2021-03-26  118.9200  120.35   94071234  121.4800    ...      120.35    NaN
#
#             symbol  uClose     uHigh      uLow   uOpen    uVolume  \
# label
# 2021-04-01    AAPL  123.00  124.1800  122.4900  123.66   75089134
# 2021-03-31    AAPL  122.15  123.5200  121.1500  121.65  118323826
# 2021-03-30    AAPL  119.90  120.4031  118.8600  120.11   85671919
# 2021-03-29    AAPL  121.39  122.5800  120.7299  121.65   80819203
# 2021-03-26    AAPL  121.21  121.4800  118.9200  120.35   94071234
#
#                         updated     volume
# label
# 2021-04-01  2021-04-02 00:48:07   75089134
# 2021-03-31  2021-04-01 00:48:05  118323826
# 2021-03-30  2021-03-31 01:16:10   85671919
# 2021-03-29  2021-03-30 01:00:08   80819203
# 2021-03-26  2021-03-27 01:16:02   94071234
#
# [5 rows x 24 columns]

# %%
# set label as DateTimeIndex
df_FB['label'] = pd.DatetimeIndex(df_FB.label)
# set index for label
df_FB= df_FB.set_index('label')
df_FB.head()
# Out:
#             change  changeOverTime  changePercent   close  fClose   fHigh  \
# label
# 2021-04-01    0.00        0.000000         0.0000  298.66  298.66  302.40
# 2021-03-31   -4.13       -0.013828        -0.0138  294.53  294.53  296.50
# 2021-03-30   -6.53       -0.035693        -0.0222  288.00  288.00  292.47
# 2021-03-29    2.82       -0.026251         0.0098  290.82  290.82  293.18
# 2021-03-26   -7.80       -0.052367        -0.0268  283.02  283.02  284.50
#
#               fLow     fOpen   fVolume    high    ...         open subkey  \
# label                                             ...
# 2021-04-01  296.60  298.4000  17615980  302.40    ...     298.4000    NaN
# 2021-03-31  288.61  289.9900  19498157  296.50    ...     289.9900    NaN
# 2021-03-30  286.70  289.8300  17474537  292.47    ...     289.8300    NaN
# 2021-03-29  284.70  285.7700  21718831  293.18    ...     285.7700    NaN
# 2021-03-26  277.77  278.3018  17629185  284.50    ...     278.3018    NaN
#
#             symbol  uClose   uHigh    uLow     uOpen   uVolume  \
# label
# 2021-04-01      FB  298.66  302.40  296.60  298.4000  17615980
# 2021-03-31      FB  294.53  296.50  288.61  289.9900  19498157
# 2021-03-30      FB  288.00  292.47  286.70  289.8300  17474537
# 2021-03-29      FB  290.82  293.18  284.70  285.7700  21718831
# 2021-03-26      FB  283.02  284.50  277.77  278.3018  17629185
#
#                         updated    volume
# label
# 2021-04-01  2021-04-02 00:48:10  17615980
# 2021-03-31  2021-04-01 00:48:04  19498157
# 2021-03-30  2021-03-31 01:16:16  17474537
# 2021-03-29  2021-03-30 01:00:05  21718831
# 2021-03-26  2021-03-27 01:16:03  17629185
#
# [5 rows x 24 columns]

# %%
# set label as DateTimeIndex
df_ADBE['label'] = pd.DatetimeIndex(df_ADBE.label)
# set index for label
df_ADBE = df_ADBE.set_index('label')
df_ADBE.head()
# Out:
#             change  changeOverTime  changePercent   close  fClose     fHigh  \
# label
# 2021-04-01    0.00        0.000000         0.0000  483.34  483.34  487.0400
# 2021-03-31   -7.97       -0.016489        -0.0165  475.37  475.37  482.4100
# 2021-03-30   -9.91       -0.036993        -0.0208  465.46  465.46  469.0925
# 2021-03-29    3.86       -0.029006         0.0083  469.32  469.32  472.0000
# 2021-03-26   -0.23       -0.029482        -0.0005  469.09  469.09  469.7700
#
#               fLow   fOpen  fVolume      high   ...       open subkey  symbol  \
# label                                           ...
# 2021-04-01  480.71  483.12  2664694  487.0400   ...     483.12    NaN    ADBE
# 2021-03-31  468.70  469.70  3155889  482.4100   ...     469.70    NaN    ADBE
# 2021-03-30  461.50  462.58  2436593  469.0925   ...     462.58    NaN    ADBE
# 2021-03-29  462.50  469.03  3142203  472.0000   ...     469.03    NaN    ADBE
# 2021-03-26  449.05  450.25  3615888  469.7700   ...     450.25    NaN    ADBE
#
#             uClose     uHigh    uLow   uOpen  uVolume              updated  \
# label
# 2021-04-01  483.34  487.0400  480.71  483.12  2664694  2021-04-02 00:48:01
# 2021-03-31  475.37  482.4100  468.70  469.70  3155889  2021-04-01 00:48:03
# 2021-03-30  465.46  469.0925  461.50  462.58  2436593  2021-03-31 01:16:09
# 2021-03-29  469.32  472.0000  462.50  469.03  3142203  2021-03-30 01:00:00
# 2021-03-26  469.09  469.7700  449.05  450.25  3615888  2021-03-27 01:16:02
#
#              volume
# label
# 2021-04-01  2664694
# 2021-03-31  3155889
# 2021-03-30  2436593
# 2021-03-29  3142203
# 2021-03-26  3615888
#
# [5 rows x 24 columns]

# %%
# set label as DateTimeIndex
df_AMD['label'] = pd.DatetimeIndex(df_AMD.label)
# set index for label
df_AMD = df_AMD.set_index('label')
df_AMD.head()
# Out:
#             change  changeOverTime  changePercent  close  fClose    fHigh  \
# label
# 2021-04-01    0.00        0.000000         0.0000  81.09   81.09  81.3100
# 2021-03-31   -2.59       -0.031940        -0.0319  78.50   78.50  79.1300
# 2021-03-30   -2.50       -0.062770        -0.0318  76.00   76.00  76.5600
# 2021-03-29    1.14       -0.048711         0.0150  77.14   77.14  78.0200
# 2021-03-26    0.27       -0.045382         0.0035  77.41   77.41  77.4995
#
#              fLow   fOpen   fVolume     high    ...       open subkey  symbol  \
# label                                           ...
# 2021-04-01  79.48  80.155  40182380  81.3100    ...     80.155    NaN     AMD
# 2021-03-31  76.52  76.570  43659455  79.1300    ...     76.570    NaN     AMD
# 2021-03-30  74.85  76.470  39169250  76.5600    ...     76.470    NaN     AMD
# 2021-03-29  76.26  77.030  37144298  78.0200    ...     77.030    NaN     AMD
# 2021-03-26  75.03  76.620  49148659  77.4995    ...     76.620    NaN     AMD
#
#             uClose    uHigh   uLow   uOpen   uVolume              updated  \
# label
# 2021-04-01   81.09  81.3100  79.48  80.155  40182380  2021-04-02 00:48:02
# 2021-03-31   78.50  79.1300  76.52  76.570  43659455  2021-04-01 00:48:04
# 2021-03-30   76.00  76.5600  74.85  76.470  39169250  2021-03-31 01:16:05
# 2021-03-29   77.14  78.0200  76.26  77.030  37144298  2021-03-30 01:00:07
# 2021-03-26   77.41  77.4995  75.03  76.620  49148659  2021-03-27 01:16:04
#
#               volume
# label
# 2021-04-01  40182380
# 2021-03-31  43659455
# 2021-03-30  39169250
# 2021-03-29  37144298
# 2021-03-26  49148659
#
# [5 rows x 24 columns]

# %%
# set label as DateTimeIndex
df_BABA['label'] = pd.DatetimeIndex(df_BABA.label)
# set index for label
df_BABA = df_BABA.set_index('label')
df_BABA.head()
# Out:
#             change  changeOverTime  changePercent   close  fClose    fHigh  \
# label
# 2021-04-01    0.00        0.000000         0.0000  224.36  224.36  231.250
# 2021-03-31    2.37        0.010563         0.0106  226.73  226.73  231.520
# 2021-03-30    2.52        0.021795         0.0111  229.25  229.25  230.450
# 2021-03-29    2.61        0.033428         0.0114  231.86  231.86  232.380
# 2021-03-26   -4.60        0.012926        -0.0198  227.26  227.26  229.239
#
#               fLow   fOpen   fVolume     high    ...       open subkey  \
# label                                            ...
# 2021-04-01  223.50  230.68  23497464  231.250    ...     230.68    NaN
# 2021-03-31  226.47  229.89  16825400  231.520    ...     229.89    NaN
# 2021-03-30  226.64  229.27  14828659  230.450    ...     229.27    NaN
# 2021-03-29  225.10  225.49  18029105  232.380    ...     225.49    NaN
# 2021-03-26  220.42  222.00  22030750  229.239    ...     222.00    NaN
#
#             symbol  uClose    uHigh    uLow   uOpen   uVolume  \
# label
# 2021-04-01    BABA  224.36  231.250  223.50  230.68  23497464
# 2021-03-31    BABA  226.73  231.520  226.47  229.89  16825400
# 2021-03-30    BABA  229.25  230.450  226.64  229.27  14828659
# 2021-03-29    BABA  231.86  232.380  225.10  225.49  18029105
# 2021-03-26    BABA  227.26  229.239  220.42  222.00  22030750
#
#                         updated    volume
# label
# 2021-04-01  2021-04-02 00:48:02  23497464
# 2021-03-31  2021-04-01 00:48:07  16825400
# 2021-03-30  2021-03-31 01:16:12  14828659
# 2021-03-29  2021-03-30 01:00:09  18029105
# 2021-03-26  2021-03-27 01:16:01  22030750
#
# [5 rows x 24 columns]

# %%
# set label as DateTimeIndex
df_INTC['label'] = pd.DatetimeIndex(df_INTC.label)
# set index for label
df_INTC = df_INTC.set_index('label')
df_INTC.head()
# Out:
#             change  changeOverTime  changePercent  close  fClose    fHigh  \
# label
# 2021-04-01    0.00        0.000000         0.0000  64.55   64.55  64.8900
# 2021-03-31   -0.55       -0.008521        -0.0085  64.00   64.00  64.4899
# 2021-03-30   -0.23       -0.012084        -0.0036  63.77   63.77  64.0000
# 2021-03-29    0.73       -0.000775         0.0114  64.50   64.50  65.1250
# 2021-03-26    0.37        0.004957         0.0057  64.87   64.87  64.9700
#
#               fLow    fOpen   fVolume     high    ...        open subkey  \
# label                                             ...
# 2021-04-01  63.575  64.7250  31416250  64.8900    ...     64.7250    NaN
# 2021-03-31  63.580  64.0100  33013231  64.4899    ...     64.0100    NaN
# 2021-03-30  63.150  63.7700  20709487  64.0000    ...     63.7700    NaN
# 2021-03-29  63.610  64.0113  26161610  65.1250    ...     64.0113    NaN
# 2021-03-26  61.770  61.8000  34705755  64.9700    ...     61.8000    NaN
#
#             symbol  uClose    uHigh    uLow    uOpen   uVolume  \
# label
# 2021-04-01    INTC   64.55  64.8900  63.575  64.7250  31416250
# 2021-03-31    INTC   64.00  64.4899  63.580  64.0100  33013231
# 2021-03-30    INTC   63.77  64.0000  63.150  63.7700  20709487
# 2021-03-29    INTC   64.50  65.1250  63.610  64.0113  26161610
# 2021-03-26    INTC   64.87  64.9700  61.770  61.8000  34705755
#
#                         updated    volume
# label
# 2021-04-01  2021-04-02 00:48:18  31416250
# 2021-03-31  2021-04-01 00:48:12  33013231
# 2021-03-30  2021-03-31 01:16:25  20709487
# 2021-03-29  2021-03-30 01:00:21  26161610
# 2021-03-26  2021-03-27 01:16:13  34705755
#
# [5 rows x 24 columns]

# %%
# set label as DateTimeIndex
df_MSFT['label'] = pd.DatetimeIndex(df_MSFT.label)
# set index for label
df_MSFT = df_MSFT.set_index('label')
df_MSFT.head()
# Out:
#             change  changeOverTime  changePercent   close  fClose   fHigh  \
# label
# 2021-04-01    0.00        0.000000         0.0000  242.35  242.35  242.84
# 2021-03-31   -6.58       -0.027151        -0.0272  235.77  235.77  239.10
# 2021-03-30   -3.92       -0.043326        -0.0166  231.85  231.85  233.85
# 2021-03-29    3.39       -0.029338         0.0146  235.24  235.24  236.80
# 2021-03-26    1.24       -0.024221         0.0053  236.48  236.48  236.71
#
#                 fLow    fOpen   fVolume    high    ...        open subkey  \
# label                                              ...
# 2021-04-01  238.0501  238.470  30337982  242.84    ...     238.470    NaN
# 2021-03-31  232.3900  232.910  43623471  239.10    ...     232.910    NaN
# 2021-03-30  231.1000  233.525  24792012  233.85    ...     233.525    NaN
# 2021-03-29  231.8800  236.590  25227455  236.80    ...     236.590    NaN
# 2021-03-26  231.5500  231.550  25479853  236.71    ...     231.550    NaN
#
#             symbol  uClose   uHigh      uLow    uOpen   uVolume  \
# label
# 2021-04-01    MSFT  242.35  242.84  238.0501  238.470  30337982
# 2021-03-31    MSFT  235.77  239.10  232.3900  232.910  43623471
# 2021-03-30    MSFT  231.85  233.85  231.1000  233.525  24792012
# 2021-03-29    MSFT  235.24  236.80  231.8800  236.590  25227455
# 2021-03-26    MSFT  236.48  236.71  231.5500  231.550  25479853
#
#                         updated    volume
# label
# 2021-04-01  2021-04-02 00:48:16  30337982
# 2021-03-31  2021-04-01 00:48:13  43623471
# 2021-03-30  2021-03-31 01:16:26  24792012
# 2021-03-29  2021-03-30 01:00:21  25227455
# 2021-03-26  2021-03-27 01:16:17  25479853
#
# [5 rows x 24 columns]

# %%
# set label as DateTimeIndex
df_PYPL['label'] = pd.DatetimeIndex(df_PYPL.label)
# set index for label
df_PYPL = df_PYPL.set_index('label')
df_PYPL.head()
# Out:
#             change  changeOverTime  changePercent   close  fClose     fHigh  \
# label
# 2021-04-01    0.00        0.000000         0.0000  247.54  247.54  252.6492
# 2021-03-31   -4.70       -0.018987        -0.0190  242.84  242.84  245.2300
# 2021-03-30   -6.30       -0.044437        -0.0259  236.54  236.54  238.3600
# 2021-03-29   -0.87       -0.047952        -0.0037  235.67  235.67  243.2000
# 2021-03-26    5.36       -0.026299         0.0227  241.03  241.03  241.3100
#
#                 fLow     fOpen  fVolume      high   ...         open subkey  \
# label                                               ...
# 2021-04-01  246.0400  248.0400  6990135  252.6492   ...     248.0400    NaN
# 2021-03-31  237.2700  238.1100  7633372  245.2300   ...     238.1100    NaN
# 2021-03-30  232.6301  236.8800  6241995  238.3600   ...     236.8800    NaN
# 2021-03-29  233.6100  241.5800  7510936  243.2000   ...     241.5800    NaN
# 2021-03-26  232.3000  233.6187  8217621  241.3100   ...     233.6187    NaN
#
#             symbol  uClose     uHigh      uLow     uOpen  uVolume  \
# label
# 2021-04-01    PYPL  247.54  252.6492  246.0400  248.0400  6990135
# 2021-03-31    PYPL  242.84  245.2300  237.2700  238.1100  7633372
# 2021-03-30    PYPL  236.54  238.3600  232.6301  236.8800  6241995
# 2021-03-29    PYPL  235.67  243.2000  233.6100  241.5800  7510936
# 2021-03-26    PYPL  241.03  241.3100  232.3000  233.6187  8217621
#
#                         updated   volume
# label
# 2021-04-01  2021-04-02 00:48:26  6990135
# 2021-03-31  2021-04-01 00:48:23  7633372
# 2021-03-30  2021-03-31 01:16:29  6241995
# 2021-03-29  2021-03-30 01:00:19  7510936
# 2021-03-26  2021-03-27 01:16:29  8217621
#
# [5 rows x 24 columns]

# %%
# set label as DateTimeIndex
df_QCOM['label'] = pd.DatetimeIndex(df_QCOM.label)
# set index for label
df_QCOM = df_QCOM.set_index('label')
df_QCOM.head()
# Out:
#             change  changeOverTime  changePercent   close  fClose     fHigh  \
# label
# 2021-04-01    0.00        0.000000         0.0000  137.79  137.79  138.4321
# 2021-03-31   -5.20       -0.037739        -0.0377  132.59  132.59  133.5200
# 2021-03-30   -2.48       -0.055737        -0.0187  130.11  130.11  131.2400
# 2021-03-29    1.16       -0.047318         0.0089  131.27  131.27  133.3400
# 2021-03-26    1.72       -0.034836         0.0131  132.99  132.99  133.3500
#
#                fLow   fOpen   fVolume      high    ...       open subkey  \
# label                                              ...
# 2021-04-01  133.600  134.50  14069555  138.4321    ...     134.50    NaN
# 2021-03-31  130.570  130.96   8361293  133.5200    ...     130.96    NaN
# 2021-03-30  129.065  130.17   7097298  131.2400    ...     130.17    NaN
# 2021-03-29  129.770  132.54   9750057  133.3400    ...     132.54    NaN
# 2021-03-26  127.040  127.06  11071560  133.3500    ...     127.06    NaN
#
#             symbol  uClose     uHigh     uLow   uOpen   uVolume  \
# label
# 2021-04-01    QCOM  137.79  138.4321  133.600  134.50  14069555
# 2021-03-31    QCOM  132.59  133.5200  130.570  130.96   8361293
# 2021-03-30    QCOM  130.11  131.2400  129.065  130.17   7097298
# 2021-03-29    QCOM  131.27  133.3400  129.770  132.54   9750057
# 2021-03-26    QCOM  132.99  133.3500  127.040  127.06  11071560
#
#                         updated    volume
# label
# 2021-04-01  2021-04-02 00:48:23  14069555
# 2021-03-31  2021-04-01 00:48:21   8361293
# 2021-03-30  2021-03-31 01:16:28   7097298
# 2021-03-29  2021-03-30 01:00:29   9750057
# 2021-03-26  2021-03-27 01:16:28  11071560
#
# [5 rows x 24 columns]

# %%
# set label as DateTimeIndex
df_SHOP['label'] = pd.DatetimeIndex(df_SHOP.label)
# set index for label
df_SHOP = df_SHOP.set_index('label')
df_SHOP.head()
# Out:
#             change  changeOverTime  changePercent    close   fClose  \
# label
# 2021-04-01    0.00        0.000000         0.0000  1155.41  1155.41
# 2021-03-31  -48.91       -0.042331        -0.0423  1106.50  1106.50
# 2021-03-30  -57.82       -0.092374        -0.0523  1048.68  1048.68
# 2021-03-29   -8.77       -0.099965        -0.0084  1039.91  1039.91
# 2021-03-26   25.30       -0.078068         0.0243  1065.21  1065.21
#
#                 fHigh     fLow    fOpen  fVolume       high   ...        open  \
# label                                                         ...
# 2021-04-01  1178.9800  1137.02  1150.00  1160189  1178.9800   ...     1150.00
# 2021-03-31  1119.5000  1065.00  1068.01  1383834  1119.5000   ...     1068.01
# 2021-03-30  1074.1873  1012.80  1028.46  1513285  1074.1873   ...     1028.46
# 2021-03-29  1075.8276  1028.60  1053.60  1055183  1075.8276   ...     1053.60
# 2021-03-26  1084.9800  1005.14  1052.60  2840193  1084.9800   ...     1052.60
#
#            subkey  symbol   uClose      uHigh     uLow    uOpen  uVolume  \
# label
# 2021-04-01    NaN    SHOP  1155.41  1178.9800  1137.02  1150.00  1160189
# 2021-03-31    NaN    SHOP  1106.50  1119.5000  1065.00  1068.01  1383834
# 2021-03-30    NaN    SHOP  1048.68  1074.1873  1012.80  1028.46  1513285
# 2021-03-29    NaN    SHOP  1039.91  1075.8276  1028.60  1053.60  1055183
# 2021-03-26    NaN    SHOP  1065.21  1084.9800  1005.14  1052.60  2840193
#
#                         updated   volume
# label
# 2021-04-01  2021-04-02 00:48:24  1160189
# 2021-03-31  2021-04-01 00:48:29  1383834
# 2021-03-30  2021-03-31 01:16:36  1513285
# 2021-03-29  2021-03-30 01:00:25  1055183
# 2021-03-26  2021-03-27 01:16:25  2840193
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Plot the trend of price from 2016 - now

# %%
df_AAPL['close'].plot(label = 'AAPL', figsize = (16,8))
df_ADBE['close'].plot(label = 'ADBE')
df_AMD['close'].plot(label = 'AMD')
df_BABA['close'].plot(label = 'BABA')
df_FB['close'].plot(label = 'FB')
df_INTC['close'].plot(label = 'INTC')
df_MSFT['close'].plot(label = 'MSFT')
df_PYPL['close'].plot(label = 'PYPL')
df_QCOM['close'].plot(label = 'QCOM')
df_SHOP['close'].plot(label = 'SHOP')
plt.legend(loc = 'center left', bbox_to_anchor=(1, 0.5))
plt.title('History trend of price', fontsize = 25)
# Out:
# Text(0.5, 1.0, 'History trend of price')

# %% [markdown]
# Most of companies/corporation in technology field have the increasing in price. <br>
# Apple has the most increasing in price, significant. <br>
# Consider:
# * Why apple increased that much
# * Which field in technology increase more than others, why?
# * There is a light decrease at the beginning of 2020, does it related to covid-19?

# %% [markdown]
# ## plot the volume of stocks from 2016 - now

# %% [markdown]
# Volume is counted as the total number of shares that are actually traded (bought and sold) during the trading day or specified set period of time. It is a measure of the total turnover of shares. Each ticket represents a trade and counted towards the total trading volume.

# %%
df_AAPL['volume'].plot(label = 'AAPL', figsize = (16,8))
df_ADBE['volume'].plot(label = 'ADBE')
df_AMD['volume'].plot(label = 'AMD')
df_BABA['volume'].plot(label = 'BABA')
df_FB['volume'].plot(label = 'FB')
df_INTC['volume'].plot(label = 'INTC')
df_MSFT['volume'].plot(label = 'MSFT')
df_PYPL['volume'].plot(label = 'PYPL')
df_QCOM['volume'].plot(label = 'QCOM')
df_SHOP['volume'].plot(label = 'SHOP')
plt.legend(loc = 'center left', bbox_to_anchor=(1, 0.5))
plt.title('History trend of volume', fontsize = 25)
# Out:
# Text(0.5, 1.0, 'History trend of volume')

# %% [markdown]
# - It's hard to see if just looking at history of volume.
# - But one thing can see is Apple still be the one was traded the most within 10 tickers.
# - And another thing is AMD appears to be traded more than other (only lesser than AAPL), while AMD does not show a clear visualization from price plot above. Why?
# - AAPL has some significant trading volume days. Check if they launch new products on those days?
# - Also AAPL volume increased significant at the beginning of 2020, while the price decreased at that time.

# %% [markdown]
# ## moving average (MA)

# %%
# AAPL
# change in one month, two weeks, 1 week, 3 days
df_AAPL['MA30'] = df_AAPL['close'].rolling(30).mean()
df_AAPL['MA14'] = df_AAPL['close'].rolling(14).mean()
df_AAPL['MA7'] = df_AAPL['close'].rolling(7).mean()
df_AAPL['MA3'] = df_AAPL['close'].rolling(3).mean()

df_AAPL[['close', 'MA30', 'MA14', 'MA7', 'MA3']].plot(label = 'AAPL', figsize = (16,8))

# %%
# ADBE
# change in one month, two weeks, 1 week, 3 days
df_ADBE['MA30'] = df_ADBE['close'].rolling(30).mean()
df_ADBE['MA14'] = df_ADBE['close'].rolling(14).mean()
df_ADBE['MA7'] = df_ADBE['close'].rolling(7).mean()
df_ADBE['MA3'] = df_ADBE['close'].rolling(3).mean()

df_ADBE[['close', 'MA30', 'MA14', 'MA7', 'MA3']].plot(figsize = (16,8))
plt.title('MA for ADBE', fontsize = 25)
# Out:
# Text(0.5, 1.0, 'MA for ADBE')

# %%
# AMD
# change in one month, two weeks, 1 week, 3 days
df_AMD['MA30'] = df_AMD['close'].rolling(30).mean()
df_AMD['MA14'] = df_AMD['close'].rolling(14).mean()
df_AMD['MA7'] = df_AMD['close'].rolling(7).mean()
df_AMD['MA3'] = df_AMD['close'].rolling(3).mean()

df_AMD[['close', 'MA30', 'MA14', 'MA7', 'MA3']].plot(figsize = (16,8))
plt.title('MA for AMD', fontsize = 25)
# Out:
# Text(0.5, 1.0, 'MA for AMD')

# %%
# BABA
# change in one month, two weeks, 1 week, 3 days
df_BABA['MA30'] = df_BABA['close'].rolling(30).mean()
df_BABA['MA14'] = df_BABA['close'].rolling(14).mean()
df_BABA['MA7'] = df_BABA['close'].rolling(7).mean()
df_BABA['MA3'] = df_BABA['close'].rolling(3).mean()

df_BABA[['close', 'MA30', 'MA14', 'MA7', 'MA3']].plot(figsize = (16,8))
plt.title('MA for BABA', fontsize = 25)
# Out:
# Text(0.5, 1.0, 'MA for BABA')

# %%
# FB
# change in one month, two weeks, 1 week, 3 days
df_FB['MA30'] = df_FB['close'].rolling(30).mean()
df_FB['MA14'] = df_FB['close'].rolling(14).mean()
df_FB['MA7'] = df_FB['close'].rolling(7).mean()
df_FB['MA3'] = df_FB['close'].rolling(3).mean()

df_FB[['close', 'MA30', 'MA14', 'MA7', 'MA3']].plot(figsize = (16,8))
plt.title('MA for FB', fontsize = 25)
# Out:
# Text(0.5, 1.0, 'MA for FB')

# %%
# INTC
# change in one month, two weeks, 1 week, 3 days
df_INTC['MA30'] = df_INTC['close'].rolling(30).mean()
df_INTC['MA14'] = df_INTC['close'].rolling(14).mean()
df_INTC['MA7'] = df_INTC['close'].rolling(7).mean()
df_INTC['MA3'] = df_INTC['close'].rolling(3).mean()

df_INTC[['close', 'MA30', 'MA14', 'MA7', 'MA3']].plot(figsize = (16,8))
plt.title('MA for INTC', fontsize = 25)
# Out:
# Text(0.5, 1.0, 'MA for INTC')

# %%
# MSFT
# change in one month, two weeks, 1 week, 3 days
df_MSFT['MA30'] = df_MSFT['close'].rolling(30).mean()
df_MSFT['MA14'] = df_MSFT['close'].rolling(14).mean()
df_MSFT['MA7'] = df_MSFT['close'].rolling(7).mean()
df_MSFT['MA3'] = df_MSFT['close'].rolling(3).mean()

df_MSFT[['close', 'MA30', 'MA14', 'MA7', 'MA3']].plot(figsize = (16,8))
plt.title('MA for MSFT', fontsize = 25)
# Out:
# Text(0.5, 1.0, 'MA for MSFT')

# %%
# PYPL
# change in one month, two weeks, 1 week, 3 days
df_PYPL['MA30'] = df_PYPL['close'].rolling(30).mean()
df_PYPL['MA14'] = df_PYPL['close'].rolling(14).mean()
df_PYPL['MA7'] =df_PYPL['close'].rolling(7).mean()
df_PYPL['MA3'] = df_PYPL['close'].rolling(3).mean()

df_PYPL[['close', 'MA30', 'MA14', 'MA7', 'MA3']].plot(figsize = (16,8))
plt.title('MA for PYPL', fontsize = 25)
# Out:
# Text(0.5, 1.0, 'MA for PYPL')

# %%
# QCOM
# change in one month, two weeks, 1 week, 3 days
df_QCOM['MA30'] = df_QCOM['close'].rolling(30).mean()
df_QCOM['MA14'] = df_QCOM['close'].rolling(14).mean()
df_QCOM['MA7'] = df_QCOM['close'].rolling(7).mean()
df_QCOM['MA3'] = df_QCOM['close'].rolling(3).mean()

df_QCOM[['close', 'MA30', 'MA14', 'MA7', 'MA3']].plot(figsize = (16,8))
plt.title('MA for QCOM', fontsize = 25)
# Out:
# Text(0.5, 1.0, 'MA for QCOM')

# %%
# SHOP
# change in one month, two weeks, 1 week, 3 days
df_SHOP['MA30'] = df_SHOP['close'].rolling(30).mean()
df_SHOP['MA14'] = df_SHOP['close'].rolling(14).mean()
df_SHOP['MA7'] = df_SHOP['close'].rolling(7).mean()
df_SHOP['MA3'] = df_SHOP['close'].rolling(3).mean()

df_SHOP[['close', 'MA30', 'MA14', 'MA7', 'MA3']].plot(figsize = (16,8))
plt.title('MA for SHOP', fontsize = 25)
# Out:
# Text(0.5, 1.0, 'MA for SHOP')

# %% [markdown]
# - smooth lines
# - some lags for longer days
# - Consider: should add MA for longer days (50 or more)???
# - up to how we want to invest, long term or short-term
